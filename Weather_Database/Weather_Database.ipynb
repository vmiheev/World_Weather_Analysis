# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import gmaps

# Import the API keys.
from config import weather_api_key
from config import g_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | kantunilkin
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | norman wells
# Processing Record 7 of Set 1 | green valley
# Processing Record 8 of Set 1 | lagoa
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | victoria
# Processing Record 11 of Set 1 | praia da vitoria
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | montepuez
# Processing Record 15 of Set 1 | popova
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 1 | qaanaaq
# Processing Record 19 of Set 1 | namatanai
# Processing Record 20 of Set 1 | narsaq
# Processing Record 21 of Set 1 | flinders
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | seoul
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | ilulissat
# Processing Record 26 of Set 1 | alice town
# Processing Record 27 of Set 1 | esperance
# Processing Record 28 of Set 1 | marsh harbour
# Processing Record 29 of Set 1 | torbay
# Processing Record 30 of Set 1 | nagua
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | kuna
# Processing Record 35 of Set 1 | krasnoselkup
# Processing Record 36 of Set 1 | ribeira grande
# Processing Record 37 of Set 1 | yecla
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | mar del plata
# Processing Record 40 of Set 1 | flin flon
# Processing Record 41 of Set 1 | castro
# Processing Record 42 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 1 | ahipara
# Processing Record 44 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | georgetown
# Processing Record 49 of Set 1 | lompoc
# Processing Record 50 of Set 1 | antofagasta
# Processing Record 1 of Set 2 | severo-kurilsk
# Processing Record 2 of Set 2 | north bend
# Processing Record 3 of Set 2 | pangnirtung
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | tombouctou
# Processing Record 6 of Set 2 | kumla
# Processing Record 7 of Set 2 | boyolangu
# Processing Record 8 of Set 2 | san patricio
# Processing Record 9 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 10 of Set 2 | ostersund
# Processing Record 11 of Set 2 | denpasar
# Processing Record 12 of Set 2 | uyovu
# Processing Record 13 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 2 | belyy yar
# Processing Record 15 of Set 2 | parati
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | new norfolk
# Processing Record 20 of Set 2 | bengkulu
# Processing Record 21 of Set 2 | alekseyevsk
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | rio grande
# Processing Record 24 of Set 2 | hobart
# Processing Record 25 of Set 2 | safakulevo
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | grand gaube
# Processing Record 28 of Set 2 | lar gerd
# City not found. Skipping...
# Processing Record 29 of Set 2 | vila
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | boa vista
# Processing Record 32 of Set 2 | zapolyarnyy
# Processing Record 33 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 34 of Set 2 | amasia
# Processing Record 35 of Set 2 | avarua
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | lorengau
# Processing Record 38 of Set 2 | hilo
# Processing Record 39 of Set 2 | dasoguz
# Processing Record 40 of Set 2 | korla
# Processing Record 41 of Set 2 | hargeysa
# Processing Record 42 of Set 2 | touros
# Processing Record 43 of Set 2 | chuy
# Processing Record 44 of Set 2 | ostrovnoy
# Processing Record 45 of Set 2 | iquique
# Processing Record 46 of Set 2 | gualmatan
# Processing Record 47 of Set 2 | thanh hoa
# Processing Record 48 of Set 2 | fortuna
# Processing Record 49 of Set 2 | portland
# Processing Record 50 of Set 2 | umm kaddadah
# Processing Record 1 of Set 3 | hokitika
# Processing Record 2 of Set 3 | sangar
# Processing Record 3 of Set 3 | horadiz
# Processing Record 4 of Set 3 | whyalla
# Processing Record 5 of Set 3 | belaya gora
# Processing Record 6 of Set 3 | mount gambier
# Processing Record 7 of Set 3 | forbes
# Processing Record 8 of Set 3 | bredasdorp
# Processing Record 9 of Set 3 | cape town
# Processing Record 10 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 3 | dabhoi
# Processing Record 12 of Set 3 | qafsah
# City not found. Skipping...
# Processing Record 13 of Set 3 | nome
# Processing Record 14 of Set 3 | talnakh
# Processing Record 15 of Set 3 | nikolskoye
# Processing Record 16 of Set 3 | magistralnyy
# Processing Record 17 of Set 3 | hobyo
# Processing Record 18 of Set 3 | muscat
# Processing Record 19 of Set 3 | bambous virieux
# Processing Record 20 of Set 3 | saint-georges
# Processing Record 21 of Set 3 | juneau
# Processing Record 22 of Set 3 | sao filipe
# Processing Record 23 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 3 | savannah bight
# Processing Record 25 of Set 3 | clyde river
# Processing Record 26 of Set 3 | mahebourg
# Processing Record 27 of Set 3 | vestmanna
# Processing Record 28 of Set 3 | dhidhdhoo
# Processing Record 29 of Set 3 | guiren
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | praia
# Processing Record 32 of Set 3 | zaraza
# Processing Record 33 of Set 3 | bethel
# Processing Record 34 of Set 3 | chardara
# Processing Record 35 of Set 3 | monroe
# Processing Record 36 of Set 3 | pemangkat
# Processing Record 37 of Set 3 | gladstone
# Processing Record 38 of Set 3 | jamestown
# Processing Record 39 of Set 3 | leshukonskoye
# Processing Record 40 of Set 3 | naze
# Processing Record 41 of Set 3 | tartagal
# Processing Record 42 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 3 | alofi
# Processing Record 44 of Set 3 | karratha
# Processing Record 45 of Set 3 | tshane
# Processing Record 46 of Set 3 | thompson
# Processing Record 47 of Set 3 | fort nelson
# Processing Record 48 of Set 3 | camargo
# Processing Record 49 of Set 3 | port elizabeth
# Processing Record 50 of Set 3 | puerto ayora
# Processing Record 1 of Set 4 | saint anthony
# Processing Record 2 of Set 4 | sikea
# City not found. Skipping...
# Processing Record 3 of Set 4 | harper
# Processing Record 4 of Set 4 | shakawe
# Processing Record 5 of Set 4 | atar
# Processing Record 6 of Set 4 | umea
# Processing Record 7 of Set 4 | beckley
# Processing Record 8 of Set 4 | leningradskiy
# Processing Record 9 of Set 4 | luanda
# Processing Record 10 of Set 4 | eyrarbakki
# Processing Record 11 of Set 4 | pittsburg
# Processing Record 12 of Set 4 | estelle
# Processing Record 13 of Set 4 | iqaluit
# Processing Record 14 of Set 4 | nador
# Processing Record 15 of Set 4 | huntsville
# Processing Record 16 of Set 4 | bowen
# Processing Record 17 of Set 4 | berea
# Processing Record 18 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 19 of Set 4 | chokurdakh
# Processing Record 20 of Set 4 | gwadar
# Processing Record 21 of Set 4 | frontera comalapa
# Processing Record 22 of Set 4 | lins
# Processing Record 23 of Set 4 | sibenik
# Processing Record 24 of Set 4 | arraial do cabo
# Processing Record 25 of Set 4 | caravelas
# Processing Record 26 of Set 4 | port hedland
# Processing Record 27 of Set 4 | longyearbyen
# Processing Record 28 of Set 4 | dauriya
# Processing Record 29 of Set 4 | teguldet
# Processing Record 30 of Set 4 | smithers
# Processing Record 31 of Set 4 | eufaula
# Processing Record 32 of Set 4 | saint-philippe
# Processing Record 33 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 4 | provideniya
# Processing Record 35 of Set 4 | severomuysk
# Processing Record 36 of Set 4 | tasiilaq
# Processing Record 37 of Set 4 | athabasca
# Processing Record 38 of Set 4 | keningau
# Processing Record 39 of Set 4 | mantua
# Processing Record 40 of Set 4 | bunia
# Processing Record 41 of Set 4 | berlevag
# Processing Record 42 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 4 | broome
# Processing Record 44 of Set 4 | do rud
# City not found. Skipping...
# Processing Record 45 of Set 4 | darhan
# Processing Record 46 of Set 4 | tazovskiy
# Processing Record 47 of Set 4 | klaksvik
# Processing Record 48 of Set 4 | winburg
# Processing Record 49 of Set 4 | anadyr
# Processing Record 50 of Set 4 | filingue
# Processing Record 1 of Set 5 | kushiro
# Processing Record 2 of Set 5 | muisne
# Processing Record 3 of Set 5 | kirkwood
# Processing Record 4 of Set 5 | oshikango
# Processing Record 5 of Set 5 | konongo
# Processing Record 6 of Set 5 | road town
# Processing Record 7 of Set 5 | kokopo
# Processing Record 8 of Set 5 | kirakira
# Processing Record 9 of Set 5 | goderich
# Processing Record 10 of Set 5 | dingle
# Processing Record 11 of Set 5 | berbera
# Processing Record 12 of Set 5 | soyo
# Processing Record 13 of Set 5 | sovetskiy
# Processing Record 14 of Set 5 | nanortalik
# Processing Record 15 of Set 5 | dicabisagan
# Processing Record 16 of Set 5 | viedma
# Processing Record 17 of Set 5 | maykain
# City not found. Skipping...
# Processing Record 18 of Set 5 | westport
# Processing Record 19 of Set 5 | vostok
# Processing Record 20 of Set 5 | sept-iles
# Processing Record 21 of Set 5 | adra
# Processing Record 22 of Set 5 | greenwood
# Processing Record 23 of Set 5 | meulaboh
# Processing Record 24 of Set 5 | jardim
# Processing Record 25 of Set 5 | neiafu
# Processing Record 26 of Set 5 | yarmouth
# Processing Record 27 of Set 5 | bluff
# Processing Record 28 of Set 5 | khani
# Processing Record 29 of Set 5 | beringovskiy
# Processing Record 30 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 31 of Set 5 | george
# Processing Record 32 of Set 5 | coihaique
# Processing Record 33 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 34 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 5 | cayenne
# Processing Record 36 of Set 5 | moose factory
# Processing Record 37 of Set 5 | ust-tsilma
# Processing Record 38 of Set 5 | chapais
# Processing Record 39 of Set 5 | tuatapere
# Processing Record 40 of Set 5 | urumqi
# Processing Record 41 of Set 5 | aracati
# Processing Record 42 of Set 5 | tamiahua
# Processing Record 43 of Set 5 | tambo
# Processing Record 44 of Set 5 | saint george
# Processing Record 45 of Set 5 | laguna
# Processing Record 46 of Set 5 | ambon
# Processing Record 47 of Set 5 | ca mau
# Processing Record 48 of Set 5 | wadi musa
# Processing Record 49 of Set 5 | richards bay
# Processing Record 50 of Set 5 | cozumel
# Processing Record 1 of Set 6 | eureka
# Processing Record 2 of Set 6 | tekirdag
# Processing Record 3 of Set 6 | akyab
# Processing Record 4 of Set 6 | hervey bay
# Processing Record 5 of Set 6 | kindu
# Processing Record 6 of Set 6 | tiksi
# Processing Record 7 of Set 6 | florianopolis
# Processing Record 8 of Set 6 | pisco
# Processing Record 9 of Set 6 | mairwa
# Processing Record 10 of Set 6 | airai
# Processing Record 11 of Set 6 | bonito
# Processing Record 12 of Set 6 | gallup
# Processing Record 13 of Set 6 | laurel
# Processing Record 14 of Set 6 | shelburne
# Processing Record 15 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 6 | nabire
# Processing Record 17 of Set 6 | sitka
# Processing Record 18 of Set 6 | meadow lake
# Processing Record 19 of Set 6 | kamenka
# Processing Record 20 of Set 6 | vite
# Processing Record 21 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 23 of Set 6 | voi
# Processing Record 24 of Set 6 | pevek
# Processing Record 25 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 6 | ancud
# Processing Record 27 of Set 6 | cidreira
# Processing Record 28 of Set 6 | acajutla
# Processing Record 29 of Set 6 | cherskiy
# Processing Record 30 of Set 6 | faanui
# Processing Record 31 of Set 6 | sao jose da coroa grande
# Processing Record 32 of Set 6 | pulandian
# Processing Record 33 of Set 6 | carnarvon
# Processing Record 34 of Set 6 | geresk
# City not found. Skipping...
# Processing Record 35 of Set 6 | balkanabat
# Processing Record 36 of Set 6 | kibala
# Processing Record 37 of Set 6 | lishui
# Processing Record 38 of Set 6 | adrar
# Processing Record 39 of Set 6 | taltal
# Processing Record 40 of Set 6 | amapa
# Processing Record 41 of Set 6 | shahpur
# Processing Record 42 of Set 6 | vaitape
# Processing Record 43 of Set 6 | geraldton
# Processing Record 44 of Set 6 | miranda de ebro
# Processing Record 45 of Set 6 | surgut
# Processing Record 46 of Set 6 | ballina
# Processing Record 47 of Set 6 | inuvik
# Processing Record 48 of Set 6 | panama city
# Processing Record 49 of Set 6 | middelburg
# Processing Record 50 of Set 6 | omboue
# Processing Record 1 of Set 7 | hauge
# Processing Record 2 of Set 7 | cap malheureux
# Processing Record 3 of Set 7 | sretensk
# Processing Record 4 of Set 7 | hope
# Processing Record 5 of Set 7 | whitehorse
# Processing Record 6 of Set 7 | borzya
# Processing Record 7 of Set 7 | yar-sale
# Processing Record 8 of Set 7 | saldanha
# Processing Record 9 of Set 7 | broken hill
# Processing Record 10 of Set 7 | nemuro
# Processing Record 11 of Set 7 | dryden
# Processing Record 12 of Set 7 | arica
# Processing Record 13 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 14 of Set 7 | haines junction
# Processing Record 15 of Set 7 | kamaishi
# Processing Record 16 of Set 7 | katsuura
# Processing Record 17 of Set 7 | olinda
# Processing Record 18 of Set 7 | loreto
# Processing Record 19 of Set 7 | henderson
# Processing Record 20 of Set 7 | bababe
# City not found. Skipping...
# Processing Record 21 of Set 7 | prince rupert
# Processing Record 22 of Set 7 | ippy
# Processing Record 23 of Set 7 | pacific grove
# Processing Record 24 of Set 7 | vila velha
# Processing Record 25 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 26 of Set 7 | maltahohe
# Processing Record 27 of Set 7 | henties bay
# Processing Record 28 of Set 7 | lethem
# Processing Record 29 of Set 7 | gizo
# Processing Record 30 of Set 7 | bathsheba
# Processing Record 31 of Set 7 | kovdor
# Processing Record 32 of Set 7 | tocopilla
# Processing Record 33 of Set 7 | cabo san lucas
# Processing Record 34 of Set 7 | oranjemund
# Processing Record 35 of Set 7 | noumea
# Processing Record 36 of Set 7 | polyarnyy
# Processing Record 37 of Set 7 | namibe
# Processing Record 38 of Set 7 | jaciara
# Processing Record 39 of Set 7 | kichera
# Processing Record 40 of Set 7 | saint-augustin
# Processing Record 41 of Set 7 | hit
# Processing Record 42 of Set 7 | bongandanga
# Processing Record 43 of Set 7 | jian
# Processing Record 44 of Set 7 | asyut
# Processing Record 45 of Set 7 | puerto baquerizo moreno
# Processing Record 46 of Set 7 | kaitangata
# Processing Record 47 of Set 7 | ishigaki
# Processing Record 48 of Set 7 | lata
# Processing Record 49 of Set 7 | inirida
# Processing Record 50 of Set 7 | sorong
# Processing Record 1 of Set 8 | cherepovets
# Processing Record 2 of Set 8 | sirjan
# Processing Record 3 of Set 8 | asau
# Processing Record 4 of Set 8 | salvacion
# Processing Record 5 of Set 8 | shizuishan
# Processing Record 6 of Set 8 | bayeux
# Processing Record 7 of Set 8 | bafoulabe
# Processing Record 8 of Set 8 | kahului
# Processing Record 9 of Set 8 | tilichiki
# Processing Record 10 of Set 8 | moussoro
# Processing Record 11 of Set 8 | maceio
# Processing Record 12 of Set 8 | mehamn
# Processing Record 13 of Set 8 | el dorado
# Processing Record 14 of Set 8 | qasigiannguit
# Processing Record 15 of Set 8 | cavalcante
# Processing Record 16 of Set 8 | constitucion
# Processing Record 17 of Set 8 | marawi
# Processing Record 18 of Set 8 | manolas
# Processing Record 19 of Set 8 | codrington
# Processing Record 20 of Set 8 | rocha
# Processing Record 21 of Set 8 | varniai
# Processing Record 22 of Set 8 | taksimo
# Processing Record 23 of Set 8 | kilindoni
# Processing Record 24 of Set 8 | ternate
# Processing Record 25 of Set 8 | beloha
# Processing Record 26 of Set 8 | kleck
# City not found. Skipping...
# Processing Record 27 of Set 8 | jacksonville
# Processing Record 28 of Set 8 | isangel
# Processing Record 29 of Set 8 | sheopur
# Processing Record 30 of Set 8 | birao
# Processing Record 31 of Set 8 | karimpur
# Processing Record 32 of Set 8 | kismayo
# Processing Record 33 of Set 8 | wajir
# Processing Record 34 of Set 8 | elko
# Processing Record 35 of Set 8 | labuhan
# Processing Record 36 of Set 8 | alihe
# Processing Record 37 of Set 8 | nuevo progreso
# Processing Record 38 of Set 8 | bandarbeyla
# Processing Record 39 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 40 of Set 8 | aguas vermelhas
# Processing Record 41 of Set 8 | santa vitoria do palmar
# Processing Record 42 of Set 8 | shieli
# Processing Record 43 of Set 8 | acapulco
# Processing Record 44 of Set 8 | hendrina
# Processing Record 45 of Set 8 | brae
# Processing Record 46 of Set 8 | acarau
# Processing Record 47 of Set 8 | luderitz
# Processing Record 48 of Set 8 | obera
# Processing Record 49 of Set 8 | aquin
# Processing Record 50 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 9 | alta floresta
# Processing Record 2 of Set 9 | thunder bay
# Processing Record 3 of Set 9 | mana
# Processing Record 4 of Set 9 | camana
# Processing Record 5 of Set 9 | ardakan
# Processing Record 6 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 7 of Set 9 | sasina
# Processing Record 8 of Set 9 | nyurba
# Processing Record 9 of Set 9 | kiama
# Processing Record 10 of Set 9 | mazatlan
# Processing Record 11 of Set 9 | vittorio veneto
# Processing Record 12 of Set 9 | el badari
# City not found. Skipping...
# Processing Record 13 of Set 9 | cartagena
# Processing Record 14 of Set 9 | troitsko-pechorsk
# Processing Record 15 of Set 9 | tevaitoa
# Processing Record 16 of Set 9 | chatellerault
# Processing Record 17 of Set 9 | carutapera
# Processing Record 18 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 9 | qinzhou
# Processing Record 20 of Set 9 | honiara
# Processing Record 21 of Set 9 | maningrida
# Processing Record 22 of Set 9 | shimoda
# Processing Record 23 of Set 9 | lahaina
# Processing Record 24 of Set 9 | hambantota
# Processing Record 25 of Set 9 | kavaratti
# Processing Record 26 of Set 9 | sayyan
# Processing Record 27 of Set 9 | tarija
# Processing Record 28 of Set 9 | aketi
# Processing Record 29 of Set 9 | busko-zdroj
# Processing Record 30 of Set 9 | rawatbhata
# Processing Record 31 of Set 9 | san ramon
# Processing Record 32 of Set 9 | yerbogachen
# Processing Record 33 of Set 9 | gurupi
# Processing Record 34 of Set 9 | diffa
# Processing Record 35 of Set 9 | sukumo
# Processing Record 36 of Set 9 | alakurtti
# Processing Record 37 of Set 9 | husavik
# Processing Record 38 of Set 9 | amos
# Processing Record 39 of Set 9 | wah
# Processing Record 40 of Set 9 | gelemso
# Processing Record 41 of Set 9 | mareeba
# Processing Record 42 of Set 9 | nizhniy kuranakh
# Processing Record 43 of Set 9 | college
# Processing Record 44 of Set 9 | port blair
# Processing Record 45 of Set 9 | zenzeli
# Processing Record 46 of Set 9 | tortoli
# Processing Record 47 of Set 9 | vila franca do campo
# Processing Record 48 of Set 9 | providencia
# Processing Record 49 of Set 9 | mount isa
# Processing Record 50 of Set 9 | ankazoabo
# Processing Record 1 of Set 10 | alekseyevka
# Processing Record 2 of Set 10 | loukhi
# Processing Record 3 of Set 10 | svetlaya
# Processing Record 4 of Set 10 | kavieng
# Processing Record 5 of Set 10 | kruisfontein
# Processing Record 6 of Set 10 | san policarpo
# Processing Record 7 of Set 10 | jining
# Processing Record 8 of Set 10 | tucumcari
# Processing Record 9 of Set 10 | walvis bay
# Processing Record 10 of Set 10 | sobolevo
# Processing Record 11 of Set 10 | fairbanks
# Processing Record 12 of Set 10 | buraydah
# Processing Record 13 of Set 10 | alpena
# Processing Record 14 of Set 10 | joniskis
# Processing Record 15 of Set 10 | yokadouma
# Processing Record 16 of Set 10 | srednekolymsk
# Processing Record 17 of Set 10 | ust-nera
# Processing Record 18 of Set 10 | dukat
# Processing Record 19 of Set 10 | lianran
# Processing Record 20 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 10 | dubbo
# Processing Record 22 of Set 10 | mbuji-mayi
# Processing Record 23 of Set 10 | ekhabi
# Processing Record 24 of Set 10 | muros
# Processing Record 25 of Set 10 | jinxi
# Processing Record 26 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 10 | toronto
# Processing Record 28 of Set 10 | dharchula
# Processing Record 29 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 30 of Set 10 | minsk
# Processing Record 31 of Set 10 | wenling
# Processing Record 32 of Set 10 | pocri
# Processing Record 33 of Set 10 | kabo
# Processing Record 34 of Set 10 | slawno
# Processing Record 35 of Set 10 | channel-port aux basques
# Processing Record 36 of Set 10 | george town
# Processing Record 37 of Set 10 | adiake
# Processing Record 38 of Set 10 | half moon bay
# Processing Record 39 of Set 10 | tra vinh
# Processing Record 40 of Set 10 | batsfjord
# Processing Record 41 of Set 10 | kokstad
# Processing Record 42 of Set 10 | aleksandrovskiy zavod
# Processing Record 43 of Set 10 | boden
# Processing Record 44 of Set 10 | suzhou
# Processing Record 45 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 46 of Set 10 | tambun
# Processing Record 47 of Set 10 | minuri
# Processing Record 48 of Set 10 | verkhnevilyuysk
# Processing Record 49 of Set 10 | hofn
# Processing Record 50 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 1 of Set 11 | deputatskiy
# Processing Record 2 of Set 11 | thano bula khan
# City not found. Skipping...
# Processing Record 3 of Set 11 | fare
# Processing Record 4 of Set 11 | ekibastuz
# Processing Record 5 of Set 11 | volsk
# Processing Record 6 of Set 11 | nowa deba
# Processing Record 7 of Set 11 | gaoual
# Processing Record 8 of Set 11 | sinnamary
# Processing Record 9 of Set 11 | erenhot
# Processing Record 10 of Set 11 | roma
# Processing Record 11 of Set 11 | karatuzskoye
# Processing Record 12 of Set 11 | bilibino
# Processing Record 13 of Set 11 | kaeo
# Processing Record 14 of Set 11 | ursulo galvan
# Processing Record 15 of Set 11 | faya
# Processing Record 16 of Set 11 | bage
# Processing Record 17 of Set 11 | monrovia
# Processing Record 18 of Set 11 | espanola
# Processing Record 19 of Set 11 | santa cruz de tenerife
# Processing Record 20 of Set 11 | bertinoro
# Processing Record 21 of Set 11 | tokat
# Processing Record 22 of Set 11 | bareli
# Processing Record 23 of Set 11 | breves
# Processing Record 24 of Set 11 | aklavik
# Processing Record 25 of Set 11 | kendari
# Processing Record 26 of Set 11 | mokrous
# Processing Record 27 of Set 11 | salaza
# Processing Record 28 of Set 11 | gazni
# City not found. Skipping...
# Processing Record 29 of Set 11 | rawson
# Processing Record 30 of Set 11 | cabedelo
# Processing Record 31 of Set 11 | zhigansk
# Processing Record 32 of Set 11 | jumla
# Processing Record 33 of Set 11 | dargaville
# Processing Record 34 of Set 11 | irkutsk
# Processing Record 35 of Set 11 | marsa matruh
# Processing Record 36 of Set 11 | shelopugino
# Processing Record 37 of Set 11 | bintulu
# Processing Record 38 of Set 11 | pauini
# Processing Record 39 of Set 11 | limon
# Processing Record 40 of Set 11 | greystones
# Processing Record 41 of Set 11 | zhenlai
# Processing Record 42 of Set 11 | solnechnyy
# Processing Record 43 of Set 11 | anshun
# Processing Record 44 of Set 11 | ushtobe
# Processing Record 45 of Set 11 | staryy nadym
# Processing Record 46 of Set 11 | nanpiao
# Processing Record 47 of Set 11 | inongo
# Processing Record 48 of Set 11 | ha giang
# Processing Record 49 of Set 11 | sciacca
# Processing Record 50 of Set 11 | yulara
# Processing Record 1 of Set 12 | bereda
# Processing Record 2 of Set 12 | egvekinot
# Processing Record 3 of Set 12 | avera
# Processing Record 4 of Set 12 | buchanan
# Processing Record 5 of Set 12 | wanning
# Processing Record 6 of Set 12 | beyneu
# Processing Record 7 of Set 12 | batetskiy
# Processing Record 8 of Set 12 | angoram
# Processing Record 9 of Set 12 | sakaiminato
# Processing Record 10 of Set 12 | itarema
# Processing Record 11 of Set 12 | evensk
# Processing Record 12 of Set 12 | nehe
# Processing Record 13 of Set 12 | richmond
# Processing Record 14 of Set 12 | port-cartier
# Processing Record 15 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 12 | ambulu
# Processing Record 17 of Set 12 | miramar
# Processing Record 18 of Set 12 | sambava
# Processing Record 19 of Set 12 | do gonbadan
# Processing Record 20 of Set 12 | plyussa
# Processing Record 21 of Set 12 | pike creek
# Processing Record 22 of Set 12 | guerrero negro
# Processing Record 23 of Set 12 | preobrazheniye
# Processing Record 24 of Set 12 | vanimo
# Processing Record 25 of Set 12 | kiunga
# Processing Record 26 of Set 12 | lewistown
# Processing Record 27 of Set 12 | itoman
# Processing Record 28 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 12 | aksarka
# Processing Record 30 of Set 12 | dali
# Processing Record 31 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 32 of Set 12 | olden
# Processing Record 33 of Set 12 | kudahuvadhoo
# Processing Record 34 of Set 12 | dibaya
# City not found. Skipping...
# Processing Record 35 of Set 12 | shahr-e kord
# Processing Record 36 of Set 12 | maragogi
# Processing Record 37 of Set 12 | kurchum
# Processing Record 38 of Set 12 | lengshuijiang
# Processing Record 39 of Set 12 | ciechanow
# Processing Record 40 of Set 12 | mocuba
# Processing Record 41 of Set 12 | salalah
# Processing Record 42 of Set 12 | koboldo
# City not found. Skipping...
# Processing Record 43 of Set 12 | christchurch
# Processing Record 44 of Set 12 | nhulunbuy
# Processing Record 45 of Set 12 | ketchikan
# Processing Record 46 of Set 12 | biak
# Processing Record 47 of Set 12 | liseleje
# Processing Record 48 of Set 12 | verkhoyansk
# Processing Record 49 of Set 12 | andilamena
# Processing Record 50 of Set 12 | grenada
# Processing Record 1 of Set 13 | parrita
# Processing Record 2 of Set 13 | trinidad
# Processing Record 3 of Set 13 | sungaipenuh
# Processing Record 4 of Set 13 | imola
# Processing Record 5 of Set 13 | byron bay
# Processing Record 6 of Set 13 | gravelbourg
# Processing Record 7 of Set 13 | usinsk
# Processing Record 8 of Set 13 | taoudenni
# Processing Record 9 of Set 13 | port augusta
# Processing Record 10 of Set 13 | kikuchi
# Processing Record 11 of Set 13 | okhotsk
# Processing Record 12 of Set 13 | pedras de fogo
# Processing Record 13 of Set 13 | margate
# Processing Record 14 of Set 13 | taranto
# Processing Record 15 of Set 13 | pierre
# Processing Record 16 of Set 13 | kaduqli
# Processing Record 17 of Set 13 | ourem
# Processing Record 18 of Set 13 | ludvika
# Processing Record 19 of Set 13 | la orilla
# Processing Record 20 of Set 13 | san juan
# Processing Record 21 of Set 13 | alice springs
# Processing Record 22 of Set 13 | sakakah
# Processing Record 23 of Set 13 | meylan
# Processing Record 24 of Set 13 | bogorodskoye
# Processing Record 25 of Set 13 | saint-francois
# Processing Record 26 of Set 13 | moron
# Processing Record 27 of Set 13 | felidhoo
# City not found. Skipping...
# Processing Record 28 of Set 13 | guiratinga
# Processing Record 29 of Set 13 | bermeo
# Processing Record 30 of Set 13 | robertsport
# Processing Record 31 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 13 | kysyl-syr
# Processing Record 33 of Set 13 | ziro
# Processing Record 34 of Set 13 | eyl
# Processing Record 35 of Set 13 | agadez
# Processing Record 36 of Set 13 | yelahanka
# Processing Record 37 of Set 13 | marystown
# Processing Record 38 of Set 13 | shimanovsk
# Processing Record 39 of Set 13 | banda aceh
# Processing Record 40 of Set 13 | canavieiras
# Processing Record 41 of Set 13 | iquitos
# Processing Record 42 of Set 13 | tessalit
# Processing Record 43 of Set 13 | banjar
# Processing Record 44 of Set 13 | puerto del rosario
# Processing Record 45 of Set 13 | almaznyy
# Processing Record 46 of Set 13 | biaora
# Processing Record 47 of Set 13 | gayny
# Processing Record 48 of Set 13 | zhezkazgan
# Processing Record 49 of Set 13 | catuday
# Processing Record 50 of Set 13 | chitral
# Processing Record 1 of Set 14 | stettler
# Processing Record 2 of Set 14 | adamas
# Processing Record 3 of Set 14 | kemin
# Processing Record 4 of Set 14 | souillac
# Processing Record 5 of Set 14 | poum
# Processing Record 6 of Set 14 | hasaki
# Processing Record 7 of Set 14 | bonthe
# Processing Record 8 of Set 14 | lubao
# Processing Record 9 of Set 14 | xining
# Processing Record 10 of Set 14 | camocim
# Processing Record 11 of Set 14 | belmonte
# Processing Record 12 of Set 14 | karachi
# Processing Record 13 of Set 14 | kloulklubed
# Processing Record 14 of Set 14 | lasa
# Processing Record 15 of Set 14 | axim
# Processing Record 16 of Set 14 | ongandjera
# Processing Record 17 of Set 14 | baturinskaya
# Processing Record 18 of Set 14 | comodoro rivadavia
# Processing Record 19 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 20 of Set 14 | abu dhabi
# Processing Record 21 of Set 14 | brandon
# Processing Record 22 of Set 14 | cururupu
# Processing Record 23 of Set 14 | mandali
# Processing Record 24 of Set 14 | shenzhen
# Processing Record 25 of Set 14 | morgan city
# Processing Record 26 of Set 14 | koslan
# Processing Record 27 of Set 14 | batagay-alyta
# Processing Record 28 of Set 14 | nanga eboko
# Processing Record 29 of Set 14 | mayna
# Processing Record 30 of Set 14 | fayaoue
# Processing Record 31 of Set 14 | naryan-mar
# Processing Record 32 of Set 14 | tallahassee
# Processing Record 33 of Set 14 | tsimlyansk
# Processing Record 34 of Set 14 | chiredzi
# Processing Record 35 of Set 14 | tigil
# Processing Record 36 of Set 14 | luceville
# City not found. Skipping...
# Processing Record 37 of Set 14 | kumba
# Processing Record 38 of Set 14 | le port
# Processing Record 39 of Set 14 | xique-xique
# Processing Record 40 of Set 14 | toora-khem
# Processing Record 41 of Set 14 | sola
# Processing Record 42 of Set 14 | buzmeyin
# Processing Record 43 of Set 14 | lucapa
# Processing Record 44 of Set 14 | bamnet narong
# Processing Record 45 of Set 14 | lalibela
# Processing Record 46 of Set 14 | san cristobal
# Processing Record 47 of Set 14 | makakilo city
# Processing Record 48 of Set 14 | tynda
# Processing Record 49 of Set 14 | halifax
# Processing Record 50 of Set 14 | quang ngai
# Processing Record 1 of Set 15 | vestmannaeyjar
# Processing Record 2 of Set 15 | mahon
# Processing Record 3 of Set 15 | dunedin
# Processing Record 4 of Set 15 | irtyshskiy
# Processing Record 5 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 6 of Set 15 | hirara
# Processing Record 7 of Set 15 | xichang
# Processing Record 8 of Set 15 | tual
# Processing Record 9 of Set 15 | kabansk
# Processing Record 10 of Set 15 | naron
# Processing Record 11 of Set 15 | wageningen
# Processing Record 12 of Set 15 | komsomolskiy
# Processing Record 13 of Set 15 | singaraja
# Processing Record 14 of Set 15 | binga
# Processing Record 15 of Set 15 | gat
# Processing Record 16 of Set 15 | natal
# Processing Record 17 of Set 15 | pushkino
# Processing Record 18 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 15 | arroyo
# Processing Record 20 of Set 15 | arrecife
# Processing Record 21 of Set 15 | namikupa
# Processing Record 22 of Set 15 | vanavara
# Processing Record 23 of Set 15 | damghan
# Processing Record 24 of Set 15 | zhucheng
# Processing Record 25 of Set 15 | belinskiy
# Processing Record 26 of Set 15 | arawa
# Processing Record 27 of Set 15 | siverek
# Processing Record 28 of Set 15 | tchollire
# Processing Record 29 of Set 15 | bushehr
# Processing Record 30 of Set 15 | neuquen
# Processing Record 31 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 32 of Set 15 | rumphi
# Processing Record 33 of Set 15 | ndele
# Processing Record 34 of Set 15 | skjervoy
# Processing Record 35 of Set 15 | cazaje
# City not found. Skipping...
# Processing Record 36 of Set 15 | urusha
# Processing Record 37 of Set 15 | barkhan
# Processing Record 38 of Set 15 | bubaque
# Processing Record 39 of Set 15 | palana
# Processing Record 40 of Set 15 | dekoa
# City not found. Skipping...
# Processing Record 41 of Set 15 | tolaga bay
# Processing Record 42 of Set 15 | jepara
# Processing Record 43 of Set 15 | barcelona
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 687

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Hermanus -34.42   19.23     60.55        70           0        5.75
# 1        Atuona  -9.80 -139.03     78.62        76           0       16.93
# 2       Ushuaia -54.80  -68.30     41.00        75          20       19.46
# 3   Kantunilkin  21.09  -87.45     89.60        66          40        8.05
# 4     Upernavik  72.79  -56.15     44.11        69          99        7.47
# 5  Norman Wells  65.28 -126.83     69.80        73          40        8.05
# 6  Green Valley  31.85 -110.99    100.99        19           1       10.29
# 7         Lagoa  39.05  -27.98     71.71        80           0       16.15
# 8        Albany  42.60  -73.97     86.00        63          75       12.08
# 9      Victoria  22.29  114.16     78.01        94         100        8.01
#
#         Description Country                 Date
# 0         clear sky      ZA  2020-08-02 20:19:04
# 1         clear sky      PF  2020-08-02 20:19:04
# 2        few clouds      AR  2020-08-02 20:19:04
# 3  scattered clouds      MX  2020-08-02 20:19:05
# 4   overcast clouds      GL  2020-08-02 20:19:05
# 5  scattered clouds      CA  2020-08-02 20:19:05
# 6         clear sky      US  2020-08-02 20:19:05
# 7         clear sky      PT  2020-08-02 20:19:05
# 8        light rain      US  2020-08-02 20:19:05
# 9        light rain      HK  2020-08-02 20:14:21

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
